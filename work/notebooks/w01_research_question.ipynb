# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
## 1. My lane (or freestyle) and why

# I chose **CTR / Engagement Opportunity Scoring** because it aligns with the starter dataset and the decision I want to support. This lane is useful when the data already includes visibility signals, and the goal is to identify pages that are visible but under-performing on clicks or engagement. That makes the output a practical ranked opportunity score for content and SEO teams.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
## 2. The question: decision, action, cost of a wrong call

# The decision I want to improve is: which visible content pages should be prioritized for CTR or engagement review. A content operations or SEO analyst can act on this by reviewing metadata, refreshing page content, checking page intent alignment, or adding better monitoring for those pages.

# I frame the cost of a wrong call as opportunity cost: if the model sends the team to a lower-potential page, review effort is wasted and higher-value opportunities are delayed. This is the right way to think about it because the team has limited time and the goal is to surface the best content opportunities first.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd
from pathlib import Path

root = Path.cwd()
print('notebook cwd:', root)
path = root.parent.parent / 'data' / 'raw' / 'content_refresh_anonymized.csv'
print('data path:', path)
df = pd.read_csv(path)

# Real evidence from the starter dataset
print('rows:', len(df))
print('unique contents:', df['content_id'].nunique())
print('unique clients:', df['client_id'].nunique())
print('impressions_90d > 0:', int((df['impressions_90d'] > 0).sum()))
print('sessions_90d > 0:', int((df['sessions_90d'] > 0).sum()))
print('mean ctr:', df['ctr'].mean())
print('mean engagement_rate:', df['engagement_rate'].mean())

# Show a small sample of relevant columns
sample = df[['content_id', 'client_id', 'impressions_90d', 'clicks_90d', 'sessions_90d', 'ctr', 'engagement_rate']].head(5)
print(sample.to_string(index=False))
# Out:
# notebook cwd: c:\Users\lukau\FlyRank_intership\work\notebooks
# data path: c:\Users\lukau\FlyRank_intership\data\raw\content_refresh_anonymized.csv
# rows: 30000
# unique contents: 30000
# unique clients: 32
# impressions_90d > 0: 30000
# sessions_90d > 0: 30000
# mean ctr: 0.5107333333333334
# mean engagement_rate: 2.53452
#           content_id         client_id  impressions_90d  clicks_90d  sessions_90d  ctr  engagement_rate
# content_304f48230142 client_f369cb89fc             3803          29            17 0.76             5.88
# content_a1fb4e703a9e client_4e07408562            15320           7             9 0.05             0.00
# content_9aa793d4d895 client_7f2253d7e2            12581          11            11 0.09             0.00
# content_331d6c4de07b client_19581e27de            11751          58            78 0.49             1.28
# content_d99b7a2d90ca client_3fdba35f04            19140          24           145 0.13             0.00

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
## 4. Careful words: what I can and can't claim

# I can claim observed patterns in the starter data: which pages have measurable impressions but lower click rates or engagement metrics, and therefore look like opportunities to improve CTR or engagement. I can say this is decision-support for content review, not an absolute prediction.

# I cannot claim causal proof, because the data only shows outcomes, not why they happened. I also cannot claim I am "predicting Google" or that the ranked score is a definitive truth — it is a ranking of likely opportunity based on observed signals in the dataset.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
